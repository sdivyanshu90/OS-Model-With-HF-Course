# %%
# !pip install transformer
# !pip install torch
# Out:
# ERROR: Could not find a version that satisfies the requirement transformer (from versions: none)
# ERROR: No matching distribution found for transformer
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.8 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 95.1 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 77.6 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 47.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.2 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 3.0 MB/s eta 0:00:000:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 12.8 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.2 MB/s eta 0:00:00:00:0100:01
# ...

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline
import torch

# %%
translator = pipeline("translation", model="facebook/nllb-200-distilled-600M",torch_dtype=torch.bfloat16)
# Out:
# Device set to use cuda:0

# %%
text = """\
My puppy is adorable, \
Your kitten is cute.
Her panda is friendly.
His llama is thoughtful. \
We all have nice pets!"""

# %%
text_translated = translator(text,
                            src_lang="eng_Latn",
                            tgt_lang="kor_Hang") #jpn_Jpan

# %%
text_translated
# Out:
# [{'translation_text': '내 강아지는 사랑스럽고, 당신의 새끼 고양이는 귀엽고, 그녀의 팬다는 친절하고, 그의 라마는 신중합니다. 우리 모두는 좋은 반려동물을 가지고 있습니다.'}]

# %%
import gc

# %%
del translator

# %%
gc.collect()
# Out:
# 6082

# %% [markdown]
# ### Build the `summarization` pipeline using 🤗 Transformers Library

# %%
summarizer = pipeline("summarization",
                     model="facebook/bart-large-cnn",
                     torch_dtype=torch.bfloat16)
# Out:
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Device set to use cuda:0

# %%
text = """Paris is the capital and most populous city of France, with
          an estimated population of 2,175,601 residents as of 2018,
          in an area of more than 105 square kilometres (41 square
          miles). The City of Paris is the centre and seat of
          government of the region and province of Île-de-France, or
          Paris Region, which has an estimated population of
          12,174,880, or about 18 percent of the population of France
          as of 2017."""

# %%
summary = summarizer(text,
                    min_length=10,
                    max_length=100)

# %%
summary
# Out:
# [{'summary_text': 'Paris is the capital and most populous city of France, with an estimated population of 2,175,601 residents as of 2018. The City of Paris is the centre and seat of the government of the region and province of Île-de-France.'}]

# %%
text2 ="""
Artificial intelligence (AI) has rapidly transformed various industries, ranging from healthcare to finance. In healthcare, AI is used for diagnostic purposes, such as identifying diseases from medical imaging with greater accuracy and speed than traditional methods. Financial institutions use AI to detect fraudulent activities and make data-driven investment decisions. Moreover, AI is playing a significant role in customer service through chatbots that can respond to queries 24/7, improving user satisfaction while reducing operational costs.

Despite its benefits, AI also raises ethical concerns. One of the main issues is the potential for bias in AI algorithms, which can lead to unfair treatment in hiring, lending, and law enforcement. Privacy is another major concern, as AI systems often require access to vast amounts of personal data to function effectively. Governments and organizations are working on regulations to ensure AI is developed and used responsibly.

As AI continues to evolve, experts believe that its future will depend on collaboration between technologists, policymakers, and society. Ensuring transparency, fairness, and accountability in AI systems will be crucial to unlocking its full potential while minimizing harm.
"""

# %%
summary2 = summarizer(text2,
                     min_length=100,
                     max_length=100)

# %%
summary2
# Out:
# [{'summary_text': 'Artificial intelligence (AI) has rapidly transformed various industries, ranging from healthcare to finance. In healthcare, AI is used for diagnostic purposes, such as identifying diseases from medical imaging with greater accuracy and speed than traditional methods. Financial institutions use AI to detect fraudulent activities and make data-driven investment decisions. AI is playing a significant role in customer service through chatbots that can respond to queries 24/7, improving user satisfaction while reducing operational costs. Despite its benefits, AI also raises ethical'}]
